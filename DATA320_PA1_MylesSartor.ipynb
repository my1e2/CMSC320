# %% [markdown]
# # CMSC320 Programming Assignment 1
# Please go through the file following the instructions as you go.
#
# When finished, download the .ipynb file and submit it on Canvas for grading.

# %% [markdown]
# ## Part 1: Getting Started
#
# - This is your first Colab notebook.
# - Rename it to `CMS320_PA1_YourName.ipynb` where `YourName` is your first and last name.
# - You can also rename the notebook to `DATA320_PA1_YourName.ipynb` if you're in the DATA section and do the same for the following assignments.

# %% [markdown]
# ## Part 2: Code Cells
# Run the code cell below to print a message. Hover over the cell until you see a play button, then press it to run the cell.

# %%
#cell 1

print("I'm doing work for 320!")
# Out:
# I'm doing work for 320!

# %% [markdown]
# Now add a new code cell just below here by selecting THIS text cell, hovering over its bottom border and pressing +Code. Put 3+2+0 in the new code cell and click run.

# %%
3+2+0
# Out:
# 5

# %% [markdown]
# ^ the 5 that should have been printed above wasn't saved anywhere. To save it, make a variable `sum` in the cell below equal to 3+2+0. Then we can **print** the value that was stored in `sum`.

# %%
#cell 2

##run the cell as is. see that you get an error.

sum = 3 + 2 + 0 #remove all the green text and add your arithmetic expression. run the cell again when finished.

print(sum)
# Out:
# 5

# %% [markdown]
# ## Part 3: Text Cells
# Double-click the cell below this one to edit it. Write a bit about yourself there. Use a couple different "things", like font sizes, text formatting, lists, etc. Be creative if you'd like. Click away from the cell to save it.

# %% [markdown]
# ### Hi, I'm Myles Sartor
#
# ###### Senior information science major specializing in data science (minor). I enjoy utilizing data to uncover valuable insights that tell unforeseen narratives for stakeholders apart of different focus areas. I'm looking forward to taking this course to enhance what I currently know about data, its use cases, and machine-learning. I find this quest for knowledge to be especially important in the modern age of technology that utilizes algorithms to such a strong degree.
#
# * My favorite color: *Red*
# * My favorite food is **mexican food**
# * The most fascinating subject is ***math***

# %% [markdown]
# ## Part 4: Combining Code and Text
# The cell below makes use of text comments (marked by #) in code cells and shows you how to print a text variable. Change "YourName" to your name and run the cell.

# %%
#cell 3

#this is a comment that is not treated as code
#print("Hi") this does nothing
name = "Myles"
print("Hello, " + name + "! Welcome to 320.")
# Out:
# Hello, Myles! Welcome to 320.

# %% [markdown]
# Note that you can't do this same thing if your variable (in this case `name`) is not a string. Run the cell below.

# %%
#cell 4

age = 22
print("Hello, it looks like you are " + age + " years old!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 #cell 4
#       3 age = 22
# ----> 4 print("Hello, it looks like you are " + age + " years old!")
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# You CAN print integers. Run the cell below.

# %%
#cell 5

print(5)
# Out:
# 5

# %% [markdown]
# What you can't do is "add" integers and strings like we tried above. To be able to concatenate an integer variable X and a string s, convert X to a string with str(X). Edit the cell below to run it without an error. Feel free to change the printed message if you'd like.

# %%
#cell 6

age = str(age)

print("Hello, it looks like you are " + age + " years old!")
# Out:
# Hello, it looks like you are 22 years old!

# %% [markdown]
# You can also print numbers and strings together in a different way. Run the cell below.

# %%
#cell 7

print(f"Hello, it looks like you are {age} years old!")
#note the f after print
# Out:
# Hello, it looks like you are 22 years old!

# %% [markdown]
# And like this too (run the cell below):

# %%
#cell 8

print("Hello, it looks like you are", age, "years old!")
# Out:
# Hello, it looks like you are 22 years old!

# %% [markdown]
# Note that in this last example the spaces around 5 are added automatically.

# %% [markdown]
# Now change the value of `age` in cell 4 where you fist defined it (choose any reasonable number). Run that cell to save the new value, and run cells 6-8 again. The 3 sentences that get printed should now show the new `age` value.
#
# Note that if you only ran cell 6 after changing the value of `age`, cells 7 and 8 would still show 5 as the age, implying that 5 is still the value of `age`. **In general, it is important not to run cells out of order. And if you change a cell far above, you should rerun all the code cells below it to reflect the new variable values.**

# %% [markdown]
# ## Part 5: Importing a package
# Python has a few built-in functions that you can use without additional imports.
# There are also a lot of packages (sets of functions) that you can import and use easily. Each package is geared towards a specific purpose. For example, NumPy is a powerful package for working with numbers that has a lot of diverse functions that work quickly on large volumes of data.

# %% [markdown]
# Run the cell below.

# %%
#cell 9

numpy.random.rand()
#this is a function from the numpy package called random.rand()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 #cell 9
# ----> 3 numpy.random.rand()
#       4 #this is a function from the numpy package called random.rand()
#
# NameError: name 'numpy' is not defined

# %% [markdown]
# That returns an error because numpy has not been imported yet. Run the cell below to import it.

# %%
#cell 10

import numpy

# %% [markdown]
# Run the cell below. This should now work.

# %%
#cell 11

numpy.random.rand()
#note that if you now run cell 9, it will also work because you've run cell 10 and numpy is now available.
#your final submission should still show an error in that first "numpy.random.rand()" cell. Part 6 will show you how to make that happen.
# Out:
# 0.6486604131242687

# %% [markdown]
# Run the cell above a few times. What kind of function do you think that is? What does it do? Double-click on THIS cell to respond.
#
# **numpy.random.rand() is a function that generates a random number (float) between 0 and 1 upon being called. This number is then stored within an array specified by the user's arguments (None are specified here). The array is what is actually being shown as output each time the function is called.**

# %% [markdown]
# ## Part 6: Submitting your work.
# 1. The `Run all` button is just below the notebook name. Click the drop-down arrow to the right of `Run all` and click `Restart session` and then `Clear all outputs`.
# 2. Run all the code cells again (either manually or by pressing `Run all`) to make sure there is no weird out-of-order artifacts.
# 3. Save this notebook (`File > Save`).
# 4. Download it to your computer as `.ipynb` (`File > Download > Download .ipynb`).
# 5. Submit the file on Canvas.

# %% [markdown]
# ## Hint: Play around with the enironment to learn how it works.
#
# For example, how do you delete a cell?
#
# ^ There is a trash can symbol at the top right of every cell upon clicking on it in the notebook. If pressed, the cell will be deleted.
#
# You can undo major actions like deleting a cell by clicking `Edit>Undo`. If you delete too much or get confused, feel free to upload the assignment again.
#
# Clicking `Restart session` and `Clear all outputs` may be helpful too.
#
# Come to office hours if you have any issues!
